# %%
pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-4.43.0-py3-none-any.whl (18.1 MB)
#      ---------------------------------------- 18.1/18.1 MB 1.0 MB/s eta 0:00:00
# Collecting orjson~=3.0
#   Downloading orjson-3.10.7-cp310-none-win_amd64.whl (137 kB)
#      ------------------------------------ 137.3/137.3 kB 907.6 kB/s eta 0:00:00
# Collecting httpx>=0.24.1
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#      -------------------------------------- 76.4/76.4 kB 703.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (1.23.5)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (3.5.0)
# Requirement already satisfied: matplotlib~=3.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (3.7.0)
# Collecting aiofiles<24.0,>=22.0
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting importlib-resources<7.0,>=1.3
#   Downloading importlib_resources-6.4.4-py3-none-any.whl (35 kB)
# Collecting typer<1.0,>=0.12
#   Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.3/47.3 kB 1.2 MB/s eta 0:00:00
# Collecting python-multipart>=0.0.9
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (1.5.3)
# Collecting ffmpy
#   Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Collecting uvicorn>=0.14.0
#   Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 1.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.19.3
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
#      ------------------------------------ 417.5/417.5 kB 839.7 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions~=4.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: markupsafe~=2.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Collecting pydantic>=2.0
#   Downloading pydantic-2.9.0-py3-none-any.whl (434 kB)
#      ------------------------------------ 434.3/434.3 kB 936.2 kB/s eta 0:00:00
# Requirement already satisfied: packaging in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (22.0)
# Collecting gradio-client==1.3.0
#   Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#      -------------------------------------- 318.7/318.7 kB 1.2 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: jinja2<4.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (6.0)
# Collecting tomlkit==0.12.0
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Collecting ruff>=0.2.2
#   Downloading ruff-0.6.4-py3-none-win_amd64.whl (8.8 MB)
#      ---------------------------------------- 8.8/8.8 MB 1.5 MB/s eta 0:00:00
# Collecting semantic-version~=2.0
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pillow<11.0,>=8.0 in d:\users\jemin\anaconda3\lib\site-packages (from gradio) (9.4.0)
# Collecting urllib3~=2.0
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ------------------------------------ 121.4/121.4 kB 889.6 kB/s eta 0:00:00
# Collecting fastapi<0.113.0
#   Downloading fastapi-0.112.4-py3-none-any.whl (93 kB)
#      -------------------------------------- 93.9/93.9 kB 899.9 kB/s eta 0:00:00
# Requirement already satisfied: fsspec in d:\users\jemin\anaconda3\lib\site-packages (from gradio-client==1.3.0->gradio) (2022.11.0)
# Collecting websockets<13.0,>=10.0
#   Downloading websockets-12.0-cp310-cp310-win_amd64.whl (124 kB)
#      -------------------------------------- 125.0/125.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in d:\users\jemin\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.0)
# Requirement already satisfied: idna>=2.8 in d:\users\jemin\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Collecting starlette<0.39.0,>=0.37.2
#   Downloading starlette-0.38.5-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.4/71.4 kB 2.0 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in d:\users\jemin\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.7.4)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in d:\users\jemin\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.28.1)
# Collecting fsspec
#   Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#      -------------------------------------- 179.3/179.3 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in d:\users\jemin\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: tqdm>=4.42.1 in d:\users\jemin\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.64.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\jemin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\jemin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\jemin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\users\jemin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\jemin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\jemin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\users\jemin\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.23.2
#   Downloading pydantic_core-2.23.2-cp310-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 1.4 MB/s eta 0:00:00
# Collecting tzdata
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      -------------------------------------- 345.4/345.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in d:\users\jemin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich>=10.11.0 in d:\users\jemin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in d:\users\jemin\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\users\jemin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\jemin\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\jemin\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      -------------------------------------- 64.9/64.9 kB 868.1 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\jemin\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in d:\users\jemin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Installing collected packages: pydub, websockets, urllib3, tzdata, tomlkit, shellingham, semantic-version, ruff, python-multipart, pydantic-core, orjson, importlib-resources, h11, fsspec, ffmpy, annotated-types, aiofiles, uvicorn, starlette, requests, pydantic, httpcore, typer, huggingface-hub, httpx, fastapi, gradio-client, gradio
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Uninstalling urllib3-1.26.14:
#       Successfully uninstalled urllib3-1.26.14
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
# Successfully installed aiofiles-23.2.1 annotated-types-0.7.0 fastapi-0.112.4 ffmpy-0.4.0 fsspec-2024.9.0 gradio-4.43.0 gradio-client-1.3.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 huggingface-hub-0.24.6 importlib-resources-6.4.4 orjson-3.10.7 pydantic-2.9.0 pydantic-core-2.23.2 pydub-0.25.1 python-multipart-0.0.9 requests-2.32.3 ruff-0.6.4 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.38.5 tomlkit-0.12.0 typer-0.12.5 tzdata-2024.1 urllib3-2.2.2 uvicorn-0.30.6 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.32.3 which is incompatible.

# %%
import gradio as gr
import numpy as np
import librosa
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras import models, layers
import matplotlib.pyplot as plt

# Load and preprocess the dataset
def extract_features(file_path, mfcc=True, chroma=True, mel=True):
    y, sr = librosa.load(file_path, mono=True)
    features = []
    if mfcc:
        mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13), axis=1)
        features.extend(mfccs)
    if chroma:
        chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr), axis=1)
        features.extend(chroma)
    if mel:
        mel = np.mean(librosa.feature.melspectrogram(y=y, sr=sr), axis=1)
        features.extend(mel)
    return features

# Function to predict scream or non-scream
def predict_audio(file_path, model, label_encoder):
    feature = extract_features(file_path)
    feature = np.array(feature).reshape(1, -1)
    prediction = model.predict(feature)
    
    predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])
    return f"Prediction: {'Scream' if predicted_label == 1 else 'Non-Scream'}"

# Define the model structure
def create_model(input_shape):
    model = models.Sequential()
    model.add(layers.Dense(256, activation='relu', input_shape=(input_shape,)))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(2, activation='softmax'))  # binary classification
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Assume the model is already trained and loaded
# You can load a pre-trained model with keras.models.load_model()
# For the sake of this example, we'll assume you have the model and label_encoder ready
input_shape = 40  # example input shape, adjust accordingly
model = create_model(input_shape)

# Simulate label encoder for demonstration
label_encoder = LabelEncoder()
label_encoder.fit([0, 1])  # 0 for non-scream, 1 for scream

# Gradio interface for uploading and predicting audio files
def gradio_predict(audio_file):
    prediction = predict_audio(audio_file, model, label_encoder)
    return prediction

# Create the Gradio interface
ui = gr.Interface(
    fn=gradio_predict, 
    inputs=gr.Audio(source="upload", type="filepath"), 
    outputs="text",
    title="Human Scream Detection",
    description="Upload an audio file to predict if it contains a scream.",
)

# Launch the Gradio interface
ui.launch()
# Out:
# D:\Users\jemin\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 64
#      59     return prediction
#      61 # Create the Gradio interface
#      62 ui = gr.Interface(
#      63     fn=gradio_predict,
# ---> 64     inputs=gr.Audio(source="upload", type="filepath"),
#      65     outputs="text",
#      66     title="Human Scream Detection",
#      67     description="Upload an audio file to predict if it contains a scream.",
#      68 )
#      70 # Launch the Gradio interface
#      71 ui.launch()
#
# File D:\Users\jemin\anaconda3\lib\site-packages\gradio\component_meta.py:167, in updateable.<locals>.wrapper(*args, **kwargs)
#     165     return None
#     166 else:
# --> 167     return fn(self, **kwargs)
#
# TypeError: Audio.__init__() got an unexpected keyword argument 'source'
